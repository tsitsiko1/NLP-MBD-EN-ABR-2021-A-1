# %% [markdown]
# # Information Retrieval Practice
#
# Elasticsearch is an open-source distributed search server built on top of Apache Lucene. It’s a great tool that allows to quickly build applications with full-text search capabilities. The core implementation is in Java, but it provides a nice REST interface which allows to interact with Elasticsearch from any programming language.

# %% [markdown]
# ## Install Elastic Search

# %% [markdown]
# To install elastic search download your the package for your platform from Get Elasticsearch
#  in https://www.elastic.co/es/start

# %% [markdown]
# ![](./download.png)

# %% [markdown]
# Once downloaded, unzip the tar.gz file and run `bin/elasticsearch` (or `bin\elasticsearch.bat` on Windows). This will launch the ElasticSearch Server. Once the server is running, by default it's accessible at [localhost:9200](http://localhost:9200).

# %% [markdown]
# ## Querying Elastic Search via Python

# %% [markdown]
# To make queries to ElasticSearch you can directly query the server endpoint via REST. However, we can make it easier via the the `elasticsearch-py` Python library. This library provides a wrapper for the REST endpoint that will allow us to query the server form Python

# %%
from elasticsearch import Elasticsearch

# %% [markdown]
# # Exercise 0: Indexing and Searching Demo for ElasticSearch

# %% [markdown]
# Now it's time to run some demo program. In this practice, we will create inverted index of sample documents (indexing) and then use Elasticsearch query grammar to search documents (searching).

# %% [markdown]
# ### Useful functions
#
# Functions to facilitate the reading of the dataset

# %%
import os, io
from collections import namedtuple

# A document class with following attributes
# filename: document filename
# text: body of documment
# path: path of document
Doc = namedtuple('Doc', 'filename path text')

def read_doc(doc_path, encoding):
    '''
        reads a document from path
        input:
            - doc_path : path of document
            - encoding: encoding
        output: =>
            - doc: instance of Doc namedtuple
    '''
    filename = doc_path.split('/')[-1]
    fp = io.open(doc_path, 'r', encoding = encoding)
    text = fp.read().strip()
    fp.close()
    return Doc(filename = filename, text = text, path = doc_path)

def read_dataset(path, encoding = "ISO-8859-1"):
    '''
        reads multiple documents from path
        input:
            - doc_path : path of document
            - encoding: encoding
        output: =>
            - docs: instances of Doc namedtuple returned as generator
    '''
    for root, dirs, files in os.walk(path):
        for doc_path in files:
            yield read_doc(root + '/' + doc_path, encoding)

# %% [markdown]
# ##  Indexing
#
# We will try to index the sample documents in `./sample_documents`. To index the documents, we first need to make a connection to **Elasticsearch**.
#
# Before we index the documents, we first need to define the **configuration of elasticsearch**. During this process, you can define basic configuration of indexer such as tokenizer, stemmer, lemmatizer, and also define which search algorithm elasticsearch will use for search.
#
# Below code shows a simple configuration settings for this demo.
# The configuration tells elasticsearch that our document `doc` will have three fields `filename`, `path`, and `text`, and we will use `text` field for search. `my_analyzer` will be used to parse the `text` field, and `my_analyzer` will also be used as a search analyzer, which will parse search queries later on. `index:False` in `filename` and `path` fields tell elasticsearch that we will not index these two fields, therefore, we cannot search these two fields with queries.
#
# The detailed documentation of analyzer can be found [here](https://www.elastic.co/guide/en/elasticsearch/reference/current/analysis.html).
#
# `"similarity": "boolean"` in `text` field will let elasticsearch know that we will use a boolean search algorithm to search `text` field. The detailed documentation of search algorithms can be found [here](https://www.elastic.co/guide/en/elasticsearch/reference/current/search.html)  and [here](https://www.elastic.co/guide/en/elasticsearch/guide/master/search-in-depth.html).

# %%
# configuration for indexing
settings = {
  "mappings": {
      "properties": {
        "filename": {
          "type": "keyword",
          "index": False,
        },
        "path": {
          "type": "keyword",
          "index": False,
        },
        "text": {
          "type": "text",
          "similarity": "boolean",
          "analyzer": "my_analyzer",
          "search_analyzer": "my_analyzer"
        }
      }
  },    
  "settings": {      
    "analysis": {
      "analyzer": {
        "my_analyzer": {
          "filter": [
            "lowercase","stop"
          ],
          "type": "custom",
          "tokenizer": "whitespace",
          "char_filter": ["my_char_filter"]
        }
      },
      "char_filter": {
        "my_char_filter": {
          "type": "html_strip",
          "escaped_tags": ["b"]
        }
      }
    }
  }
}

# %% [markdown]
# Now we will retrieve `sample documents` and indexing them into `INDEX_NAME` index. To that end, the following 2 functions will help you in the creation of the index and the indexing of the documents.

# %%
from elasticsearch import Elasticsearch

ES_HOSTS = ['http://localhost:9200']
INDEX_NAME = 'sample_index'
DOCS_PATH = 'practice_data/sample_documents'

def create_index(es_conn, index_name, settings):
    '''
        create index structure in elasticsearch server. 
        If index_name exists in the server, it will be removed, and new index will be created.
        input:
            - es_conn: elasticsearch connection object
            - index_name: name of index to create
            - settings: settings and mappings for index to create
        output: =>
            - None
    '''
    if es_conn.indices.exists(index_name):
        es_conn.indices.delete(index = index_name)
        print('index `{}` deleted'.format(index_name))
    es_conn.indices.create(index = index_name, body = settings)
    print('index `{}` created'.format(index_name))            
            
def build_index(es_conn, dataset, index_name, settings, DOC_TYPE='doc'):
    '''
        build index from a collection of documents
        input:
            - es_conn: elasticsearch connection object
            - dataset: iterable, collection of namedtuple Doc objects
            - index_name: name of the index where the documents will be stored
            - DOC_TYPE: type signature of documents
    '''
    # create the index if it doesn't exist
    create_index(es_conn = es_conn, index_name = index_name, settings=settings)
    counter_read, counter_idx_failed = 0, 0 # counters

    # retrive & index documents
    for doc in dataset:
        res = es_conn.index(
            index = index_name,
            id = doc.filename,
            body = doc._asdict())
        counter_read += 1

        if res['result'] != 'created':
            conter_idx_failed += 1
        else:
            print('indexed {} documents'.format(counter_read))

    print('indexed {} docs to index `{}`, failed to index {} docs'.format(
        counter_read,
        index_name,
        counter_idx_failed
    ))
    
    # refresh after indexing
    es_conn.indices.refresh(index=index_name)  

es_conn = Elasticsearch(ES_HOSTS)
dataset = read_dataset(DOCS_PATH)
build_index(es_conn, dataset, INDEX_NAME, settings)
# Out:
# index `sample_index` deleted
# index `sample_index` created
# indexed 1 documents
# indexed 2 documents
# indexed 3 documents
# indexed 4 documents
# indexed 5 documents
# indexed 5 docs to index `sample_index`, failed to index 0 docs

# %% [markdown]
# We successfully created an inverted index for the sample documents in `./sample/documents`. It's time to search the documents with some queries.

# %% [markdown]
# ## Searching

# %% [markdown]
# **Elasticsearch** supports a specific query grammar which intends to replicate the grammar of traditional search engines (Google Search supports a similar grammar).
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl.html
#
# To understand score of the result, check: https://www.elastic.co/guide/en/elasticsearch/guide/current/relevance-intro.html#explain

# %% [markdown]
# ### Useful Functions
#
# These functions will help you with the ElasticSearch output format in order to visualize the search results

# %%
def extract_response(res):
    if res is not None:
        for hit in res['hits']['hits']:
            filename = hit["_source"]["filename"]
            score = hit["_score"]
            
            yield (filename, score)

def print_result(query, res):
    # formatter of searched result
    matches = extract_response(res)
    if matches is not None:
        for match in sorted(matches, key = lambda x: -x[1]):
            print('{}, {}, {},\n'.format(
                query,
                match[0], # filename
                match[1], # score
            ))

# %% [markdown]
# We will perform now different types of queries.
#
# First, a query with a single term

# %%
res = es_conn.search(index = INDEX_NAME,
    body={
          "query": {
            "bool": {
              "must": [
                {
                  "match": {"text": "Obama"}
                }
              ]
            }
          }
        }
    )
print_result("Obama", res)
# Out:
# Obama, doc1.txt, 1.0,
#
# Obama, doc3.txt, 1.0,
#
# Obama, doc5.txt, 1.0,
#
# Obama, doc2.txt, 1.0,

# %% [markdown]
# Now a query for the documents containing both terms

# %%
# Boolean Query "Obama AND Hillary"
res = es_conn.search(index = INDEX_NAME,
    body={
          "query": {
            "match" : {
              "text" : {
                "query" : "Obama Hillary",
                "operator" : "and"
              }
            }
          }
        }
    )
print_result("Obama AND Hillary", res)
# Out:
# Obama AND Hillary, doc1.txt, 2.0,

# %% [markdown]
# And now containing a term but NOT the other.

# %%
# Boolean Query "Obama BUT Hillary"
res = es_conn.search(index = INDEX_NAME,
    body={
          "query": {
            "bool": {
              "must": [
                {
                    "match": {"text": "Obama"}
                }
              ],
              "must_not":[
                {
                    "match": {"text": "Hillary"}
                }
              ]
            }
          }
        }
    )
print_result("Obama BUT Hillary", res)
# Out:
# Obama BUT Hillary, doc3.txt, 1.0,
#
# Obama BUT Hillary, doc5.txt, 1.0,
#
# Obama BUT Hillary, doc2.txt, 1.0,

# %% [markdown]
# Finally, the default behaviour for queries with more than one term: OR.

# %%
# Boolean Query "Obama OR Hillary"
# default is OR
res = es_conn.search(index = INDEX_NAME,
    body={
          "query": {
            "match" : {
              "text" : {
                "query" : "Obama Hillary",
              }
            }
          }
        }
    )
print_result("Obama OR Hillary", res)
# Out:
# Obama OR Hillary, doc1.txt, 2.0,
#
# Obama OR Hillary, doc3.txt, 1.0,
#
# Obama OR Hillary, doc5.txt, 1.0,
#
# Obama OR Hillary, doc4.txt, 1.0,
#
# Obama OR Hillary, doc2.txt, 1.0,

# %% [markdown]
# # Exercise 1: Evaluating Results

# %% [markdown]
# We will show how the retrieved result can be evaluated by **trec_eval** evaluation program.
#
# **trec_eval** is the standard software for evaluating search engines with test collections.

# %% [markdown]
# ## TREC_EVAL setup
#
# First, we need to install `trec_eval`. To install
#
# - unzip `trec_eval-master.zip`
# - go to `trec_eval-master` folder
# - run shell command `make` to create `trec_eval` binary file (If your are using Windows, you can install `make` from [here](http://gnuwin32.sourceforge.net/packages/make.htm))

# %% [markdown]
# Next, check the `government` folder which contains three things:
#
# - A set of documents needed to be indexed, in the *documents* directory.
#
# - A set of queries, also called 'topics', in *topics/gov.topics* file. The format of **.topic* file is "query_id query_terms". For example, the first line of 'air.topics' file is
#
#     `1 mining gold silver coal`
#
#     which means that the ID of query is *01* and the corresponding query is *mining gold silver coal*.
#
# - A set of judgements, saying which documents are relevant for each query, in the *qrels/gov.qrels* file. The format of **.qrels* file is "query_id 0 document_name binary_relevance". For example, the first line of 'air.qrels' is
#
#     `1 0 G00-00-0681214 0`
#
#     which means that the document `G00-00-0681214` is not relevant to the given query id *01*. The binary relevance is *1* if the file is relevant to the query, otherwise *0*. Please ignore the second argument *0* as it is always *0*.

# %% [markdown]
# ## Create new index
#
# In the previous exercise, we have created the index (inverted-index) of five sample documents. In this one, you will create a new index with the documents in `government/documents` folder .
#
# To build a new index, you first need to create a new index. Note that `EVAL_INDEX_NAME` should be changed in order to build separate index for the documents in `government/documents`.
#
# After creating the new configuration file, now your job is to create the new index reusing the code in the previous exercise.

# %%
settings = {
  "mappings": {
      "properties": {
        "filename": {
          "type": "keyword",
          "index": False,
        },
        "path": {
          "type": "keyword",
          "index": False,
        },
        "text": {
          "type": "text",
          "similarity": "boolean",
          "analyzer": "my_analyzer",
          "search_analyzer": "my_analyzer"
        }
      }
  },    
  "settings": {      
    "analysis": {
      "analyzer": {
        "my_analyzer": {
          "filter": [
            "stop"
          ],
          "char_filter": [
            "html_strip"
          ],
          "type": "custom",
          "tokenizer": "whitespace"
        }
      }
    }
  }
}

# %% [markdown]
# ### Exercise 1.1: Create the new index
#
# You can reuse the previous code

# %%
ES_HOSTS = ['http://localhost:9200']
EVAL_INDEX_NAME = 'government'
EVAL_DOCS_PATH = 'practice_data/government/documents'

# Your code here

# %% [markdown]
# ### Exercise 1.2. Read topics and produce result file
#
# Read topics (queries) from a file (`government/topics/gov.topics`) and then search documents indexed by **Elasticsearch**. You may choose one of search algorithms.
#
# Produce result file (e.g., *retrieved.txt*) according to **trec_eval** standard output format:
#
# `01 Q0 document1 0 1.23 my_IR_system1`
#
# `01 Q0 document2 1 1.08 my_IR_system1`
#
# where '01' is the query ID; ignore 'Q0'; 'documentX' is the name of the file; '0' (or '1' or some other integer number) is the rank of this result; '1.23' (or '1.08' or some other number) is the score of this result; and 'my_IR_system1' is the name for your retrieval system. In particular, note that the rank field will be ignored in **trec_eval**; internally ranks are assigned by sorting by the score field with ties broken deterministicly (using file name).
#
# **Now here's your first job**
#
# 1. read `gov.topics` file line by line,
# 2. send query to the elastic search
# 3. write output according the the output format described above

# %%
# Your code here

# %% [markdown]
# ### Exercise 1.3.  Evaluation
#
# It's time to run **trec_eval** which compares the qrels file provided in *gov.qrels* with your result file. (hint: adding a **!** and shell commands allow you to execute shell commands in jupyter-notebook, e.g. `!ls`)
#
# TREC_EVAL will evaluate the performance of your search engine. To evaluate your search result, you first need two sets of files: the retrieved result file and the ground truth file.
# Let's say your retrieval result is saved at `retrieved.txt`, and the ground truth file is saved at `gov.qrels`. The performance of your retrieval can be measured via:
#
# ```
# ./trec_eval.9.0/trec_eval  gov.qrels retrieved.txt
# ```

# %%
# Your code here

# %% [markdown]
# If **trec_eval** runs correctly and produces numbers which you think are sensible, you are done with this part. You might want to look at the output, though, and get some understanding of what it means; later you will be asked to interpret this and to choose evaluation measures you prefer.
#
# Running `./trec_eval.9.0/trec_eval -h` will list all the options available.

# %% [markdown]
# # Improving the Index

# %% [markdown]
# The baseline retrieval that we have proposed before did offer a rather low performance. In order to improve it, we can tune the index setting to include some of the NLP processing that we have learned (e.g., stemming, stopwords, ...)-
#
# To that end, review the documentation of analyzer [here](https://www.elastic.co/guide/en/elasticsearch/reference/current/analysis.html).

# %% [markdown]
# Although we could generate our own analyzers (as we did in the previous exercises with `my_analyzer`), Elasticsearch provides a set of predefined analyzers for the different languages. More information [here](https://www.elastic.co/guide/en/elasticsearch/reference/current/analysis-lang-analyzer.html).
#
# In particular, we are going to use the `English Analyzer`

# %% [markdown]
# In addition, we can modify the index to use a more sophisticated similarity measure (e.g., `BM25`) than the binary similarity.

# %% [markdown]
# ## Exercise 2.1 English Analyzer + BM25

# %% [markdown]
# Modify the settings to apply the `English Analyzer` and use the `BM25` similarity

# %%
new_settings = {  
# Your code here
}

# %% [markdown]
# With this new settings we will create a new index, generate a new result file and evaluate it by means of the `trec_eval`

# %%
ES_HOSTS = ['http://localhost:9200']
EVAL_INDEX_NAME = 'government'
EVAL_DOCS_PATH = 'practice_data/government/documents'

es_conn = Elasticsearch(ES_HOSTS)
dataset = read_dataset(EVAL_DOCS_PATH)
build_index(es_conn, dataset, EVAL_INDEX_NAME, new_settings)
# Out:
# index `government` deleted
# index `government` created
# indexed 1 documents
# indexed 2 documents
# indexed 3 documents
# indexed 4 documents
# indexed 5 documents
# indexed 6 documents
# indexed 7 documents
# indexed 8 documents
# indexed 9 documents
# indexed 10 documents
# indexed 11 documents
# indexed 12 documents
# indexed 13 documents
# indexed 14 documents
# indexed 15 documents
# indexed 16 documents
# indexed 17 documents
# indexed 18 documents
# indexed 19 documents
# indexed 20 documents
# indexed 21 documents
# indexed 22 documents
# indexed 23 documents
# indexed 24 documents
# indexed 25 documents
# indexed 26 documents
# indexed 27 documents
# indexed 28 documents
# indexed 29 documents
# indexed 30 documents
# indexed 31 documents
# indexed 32 documents
# indexed 33 documents
# indexed 34 documents
# indexed 35 documents
# indexed 36 documents
# indexed 37 documents
# indexed 38 documents
# indexed 39 documents
# indexed 40 documents
# indexed 41 documents
# indexed 42 documents
# indexed 43 documents
# indexed 44 documents
# indexed 45 documents
# indexed 46 documents
# indexed 47 documents
# indexed 48 documents
# indexed 49 documents
# indexed 50 documents
# indexed 51 documents
# indexed 52 documents
# indexed 53 documents
# indexed 54 documents
# indexed 55 documents
# indexed 56 documents
# indexed 57 documents
# indexed 58 documents
# indexed 59 documents
# indexed 60 documents
# indexed 61 documents
# indexed 62 documents
# indexed 63 documents
# indexed 64 documents
# indexed 65 documents
# indexed 66 documents
# indexed 67 documents
# indexed 68 documents
# indexed 69 documents
# indexed 70 documents
# indexed 71 documents
# indexed 72 documents
# indexed 73 documents
# indexed 74 documents
# indexed 75 documents
# indexed 76 documents
# indexed 77 documents
# indexed 78 documents
# indexed 79 documents
# indexed 80 documents
# indexed 81 documents
# indexed 82 documents
# indexed 83 documents
# indexed 84 documents
# indexed 85 documents
# indexed 86 documents
# indexed 87 documents
# indexed 88 documents
# indexed 89 documents
# indexed 90 documents
# indexed 91 documents
# indexed 92 documents
# indexed 93 documents
# indexed 94 documents
# indexed 95 documents
# indexed 96 documents
# indexed 97 documents
# indexed 98 documents
# indexed 99 documents
# indexed 100 documents
# indexed 101 documents
# indexed 102 documents
# indexed 103 documents
# indexed 104 documents
# indexed 105 documents
# indexed 106 documents
# indexed 107 documents
# indexed 108 documents
# indexed 109 documents
# indexed 110 documents
# indexed 111 documents
# indexed 112 documents
# indexed 113 documents
# indexed 114 documents
# indexed 115 documents
# indexed 116 documents
# indexed 117 documents
# indexed 118 documents
# indexed 119 documents
# indexed 120 documents
# indexed 121 documents
# indexed 122 documents
# indexed 123 documents
# indexed 124 documents
# indexed 125 documents
# indexed 126 documents
# indexed 127 documents
# indexed 128 documents
# indexed 129 documents
# indexed 130 documents
# indexed 131 documents
# indexed 132 documents
# indexed 133 documents
# indexed 134 documents
# indexed 135 documents
# indexed 136 documents
# indexed 137 documents
# indexed 138 documents
# indexed 139 documents
# indexed 140 documents
# indexed 141 documents
# indexed 142 documents
# indexed 143 documents
# indexed 144 documents
# indexed 145 documents
# indexed 146 documents
# indexed 147 documents
# indexed 148 documents
# indexed 149 documents
# indexed 150 documents
# indexed 151 documents
# indexed 152 documents
# indexed 153 documents
# indexed 154 documents
# indexed 155 documents
# indexed 156 documents
# indexed 157 documents
# indexed 158 documents
# indexed 159 documents
# indexed 160 documents
# indexed 161 documents
# indexed 162 documents
# indexed 163 documents
# indexed 164 documents
# indexed 165 documents
# indexed 166 documents
# indexed 167 documents
# indexed 168 documents
# indexed 169 documents
# indexed 170 documents
# indexed 171 documents
# indexed 172 documents
# indexed 173 documents
# indexed 174 documents
# indexed 175 documents
# indexed 176 documents
# indexed 177 documents
# indexed 178 documents
# indexed 179 documents
# indexed 180 documents
# indexed 181 documents
# indexed 182 documents
# indexed 183 documents
# indexed 184 documents
# indexed 185 documents
# indexed 186 documents
# indexed 187 documents
# indexed 188 documents
# indexed 189 documents
# indexed 190 documents
# indexed 191 documents
# indexed 192 documents
# indexed 193 documents
# indexed 194 documents
# indexed 195 documents
# indexed 196 documents
# indexed 197 documents
# indexed 198 documents
# indexed 199 documents
# indexed 200 documents
# indexed 201 documents
# indexed 202 documents
# indexed 203 documents
# indexed 204 documents
# indexed 205 documents
# indexed 206 documents
# indexed 207 documents
# indexed 208 documents
# indexed 209 documents
# indexed 210 documents
# indexed 211 documents
# indexed 212 documents
# indexed 213 documents
# indexed 214 documents
# indexed 215 documents
# indexed 216 documents
# indexed 217 documents
# indexed 218 documents
# indexed 219 documents
# indexed 220 documents
# indexed 221 documents
# indexed 222 documents
# indexed 223 documents
# indexed 224 documents
# indexed 225 documents
# indexed 226 documents
# indexed 227 documents
# indexed 228 documents
# indexed 229 documents
# indexed 230 documents
# indexed 231 documents
# indexed 232 documents
# indexed 233 documents
# indexed 234 documents
# indexed 235 documents
# indexed 236 documents
# indexed 237 documents
# indexed 238 documents
# indexed 239 documents
# indexed 240 documents
# indexed 241 documents
# indexed 242 documents
# indexed 243 documents
# indexed 244 documents
# indexed 245 documents
# indexed 246 documents
# indexed 247 documents
# indexed 248 documents
# indexed 249 documents
# indexed 250 documents
# indexed 251 documents
# indexed 252 documents
# indexed 253 documents
# indexed 254 documents
# indexed 255 documents
# indexed 256 documents
# indexed 257 documents
# indexed 258 documents
# indexed 259 documents
# indexed 260 documents
# indexed 261 documents
# indexed 262 documents
# indexed 263 documents
# indexed 264 documents
# indexed 265 documents
# indexed 266 documents
# indexed 267 documents
# indexed 268 documents
# indexed 269 documents
# indexed 270 documents
# indexed 271 documents
# indexed 272 documents
# indexed 273 documents
# indexed 274 documents
# indexed 275 documents
# indexed 276 documents
# indexed 277 documents
# indexed 278 documents
# indexed 279 documents
# indexed 280 documents
# indexed 281 documents
# indexed 282 documents
# indexed 283 documents
# indexed 284 documents
# indexed 285 documents
# indexed 286 documents
# indexed 287 documents
# indexed 288 documents
# indexed 289 documents
# indexed 290 documents
# indexed 291 documents
# indexed 292 documents
# indexed 293 documents
# indexed 294 documents
# indexed 295 documents
# indexed 296 documents
# indexed 297 documents
# indexed 298 documents
# indexed 299 documents
# indexed 300 documents
# indexed 301 documents
# indexed 302 documents
# indexed 303 documents
# indexed 304 documents
# indexed 305 documents
# indexed 306 documents
# indexed 307 documents
# indexed 308 documents
# indexed 309 documents
# indexed 310 documents
# indexed 311 documents
# indexed 312 documents
# indexed 313 documents
# indexed 314 documents
# indexed 315 documents
# indexed 316 documents
# indexed 317 documents
# indexed 318 documents
# indexed 319 documents
# indexed 320 documents
# indexed 321 documents
# indexed 322 documents
# indexed 323 documents
# indexed 324 documents
# indexed 325 documents
# indexed 326 documents
# indexed 327 documents
# indexed 328 documents
# indexed 329 documents
# indexed 330 documents
# indexed 331 documents
# indexed 332 documents
# indexed 333 documents
# indexed 334 documents
# indexed 335 documents
# indexed 336 documents
# indexed 337 documents
# indexed 338 documents
# indexed 339 documents
# indexed 340 documents
# indexed 341 documents
# indexed 342 documents
# indexed 343 documents
# indexed 344 documents
# indexed 345 documents
# indexed 346 documents
# indexed 347 documents
# indexed 348 documents
# indexed 349 documents
# indexed 350 documents
# indexed 351 documents
# indexed 352 documents
# indexed 353 documents
# indexed 354 documents
# indexed 355 documents
# indexed 356 documents
# indexed 357 documents
# indexed 358 documents
# indexed 359 documents
# indexed 360 documents
# indexed 361 documents
# indexed 362 documents
# indexed 363 documents
# indexed 364 documents
# indexed 365 documents
# indexed 366 documents
# indexed 367 documents
# indexed 368 documents
# indexed 369 documents
# indexed 370 documents
# indexed 371 documents
# indexed 372 documents
# indexed 373 documents
# indexed 374 documents
# indexed 375 documents
# indexed 376 documents
# indexed 377 documents
# indexed 378 documents
# indexed 379 documents
# indexed 380 documents
# indexed 381 documents
# indexed 382 documents
# indexed 383 documents
# indexed 384 documents
# indexed 385 documents
# indexed 386 documents
# indexed 387 documents
# indexed 388 documents
# indexed 389 documents
# indexed 390 documents
# indexed 391 documents
# indexed 392 documents
# indexed 393 documents
# indexed 394 documents
# indexed 395 documents
# indexed 396 documents
# indexed 397 documents
# indexed 398 documents
# indexed 399 documents
# indexed 400 documents
# indexed 401 documents
# indexed 402 documents
# indexed 403 documents
# indexed 404 documents
# indexed 405 documents
# indexed 406 documents
# indexed 407 documents
# indexed 408 documents
# indexed 409 documents
# indexed 410 documents
# indexed 411 documents
# indexed 412 documents
# indexed 413 documents
# indexed 414 documents
# indexed 415 documents
# indexed 416 documents
# indexed 417 documents
# indexed 418 documents
# indexed 419 documents
# indexed 420 documents
# indexed 421 documents
# indexed 422 documents
# indexed 423 documents
# indexed 424 documents
# indexed 425 documents
# indexed 426 documents
# indexed 427 documents
# indexed 428 documents
# indexed 429 documents
# indexed 430 documents
# indexed 431 documents
# indexed 432 documents
# indexed 433 documents
# indexed 434 documents
# indexed 435 documents
# indexed 436 documents
# indexed 437 documents
# indexed 438 documents
# indexed 439 documents
# indexed 440 documents
# indexed 441 documents
# indexed 442 documents
# indexed 443 documents
# indexed 444 documents
# indexed 445 documents
# indexed 446 documents
# indexed 447 documents
# indexed 448 documents
# indexed 449 documents
# indexed 450 documents
# indexed 451 documents
# indexed 452 documents
# indexed 453 documents
# indexed 454 documents
# indexed 455 documents
# indexed 456 documents
# indexed 457 documents
# indexed 458 documents
# indexed 459 documents
# indexed 460 documents
# indexed 461 documents
# indexed 462 documents
# indexed 463 documents
# indexed 464 documents
# indexed 465 documents
# indexed 466 documents
# indexed 467 documents
# indexed 468 documents
# indexed 469 documents
# indexed 470 documents
# indexed 471 documents
# indexed 472 documents
# indexed 473 documents
# indexed 474 documents
# indexed 475 documents
# indexed 476 documents
# indexed 477 documents
# indexed 478 documents
# indexed 479 documents
# indexed 480 documents
# indexed 481 documents
# indexed 482 documents
# indexed 483 documents
# indexed 484 documents
# indexed 485 documents
# indexed 486 documents
# indexed 487 documents
# indexed 488 documents
# indexed 489 documents
# indexed 490 documents
# indexed 491 documents
# indexed 492 documents
# indexed 493 documents
# indexed 494 documents
# indexed 495 documents
# indexed 496 documents
# indexed 497 documents
# indexed 498 documents
# indexed 499 documents
# indexed 500 documents
# indexed 501 documents
# indexed 502 documents
# indexed 503 documents
# indexed 504 documents
# indexed 505 documents
# indexed 506 documents
# indexed 507 documents
# indexed 508 documents
# indexed 509 documents
# indexed 510 documents
# indexed 511 documents
# indexed 512 documents
# indexed 513 documents
# indexed 514 documents
# indexed 515 documents
# indexed 516 documents
# indexed 517 documents
# indexed 518 documents
# indexed 519 documents
# indexed 520 documents
# indexed 521 documents
# indexed 522 documents
# indexed 523 documents
# indexed 524 documents
# indexed 525 documents
# indexed 526 documents
# indexed 527 documents
# indexed 528 documents
# indexed 529 documents
# indexed 530 documents
# indexed 531 documents
# indexed 532 documents
# indexed 533 documents
# indexed 534 documents
# indexed 535 documents
# indexed 536 documents
# indexed 537 documents
# indexed 538 documents
# indexed 539 documents
# indexed 540 documents
# indexed 541 documents
# indexed 542 documents
# indexed 543 documents
# indexed 544 documents
# indexed 545 documents
# indexed 546 documents
# indexed 547 documents
# indexed 548 documents
# indexed 549 documents
# indexed 550 documents
# indexed 551 documents
# indexed 552 documents
# indexed 553 documents
# indexed 554 documents
# indexed 555 documents
# indexed 556 documents
# indexed 557 documents
# indexed 558 documents
# indexed 559 documents
# indexed 560 documents
# indexed 561 documents
# indexed 562 documents
# indexed 563 documents
# indexed 564 documents
# indexed 565 documents
# indexed 566 documents
# indexed 567 documents
# indexed 568 documents
# indexed 569 documents
# indexed 570 documents
# indexed 571 documents
# indexed 572 documents
# indexed 573 documents
# indexed 574 documents
# indexed 575 documents
# indexed 576 documents
# indexed 577 documents
# indexed 578 documents
# indexed 579 documents
# indexed 580 documents
# indexed 581 documents
# indexed 582 documents
# indexed 583 documents
# indexed 584 documents
# indexed 585 documents
# indexed 586 documents
# indexed 587 documents
# indexed 588 documents
# indexed 589 documents
# indexed 590 documents
# indexed 591 documents
# indexed 592 documents
# indexed 593 documents
# indexed 594 documents
# indexed 595 documents
# indexed 596 documents
# indexed 597 documents
# indexed 598 documents
# indexed 599 documents
# indexed 600 documents
# indexed 601 documents
# indexed 602 documents
# indexed 603 documents
# indexed 604 documents
# indexed 605 documents
# indexed 606 documents
# indexed 607 documents
# indexed 608 documents
# indexed 609 documents
# indexed 610 documents
# indexed 611 documents
# indexed 612 documents
# indexed 613 documents
# indexed 614 documents
# indexed 615 documents
# indexed 616 documents
# indexed 617 documents
# indexed 618 documents
# indexed 619 documents
# indexed 620 documents
# indexed 621 documents
# indexed 622 documents
# indexed 623 documents
# indexed 624 documents
# indexed 625 documents
# indexed 626 documents
# indexed 627 documents
# indexed 628 documents
# indexed 629 documents
# indexed 630 documents
# indexed 631 documents
# indexed 632 documents
# indexed 633 documents
# indexed 634 documents
# indexed 635 documents
# indexed 636 documents
# indexed 637 documents
# indexed 638 documents
# indexed 639 documents
# indexed 640 documents
# indexed 641 documents
# indexed 642 documents
# indexed 643 documents
# indexed 644 documents
# indexed 645 documents
# indexed 646 documents
# indexed 647 documents
# indexed 648 documents
# indexed 649 documents
# indexed 650 documents
# indexed 651 documents
# indexed 652 documents
# indexed 653 documents
# indexed 654 documents
# indexed 655 documents
# indexed 656 documents
# indexed 657 documents
# indexed 658 documents
# indexed 659 documents
# indexed 660 documents
# indexed 661 documents
# indexed 662 documents
# indexed 663 documents
# indexed 664 documents
# indexed 665 documents
# indexed 666 documents
# indexed 667 documents
# indexed 668 documents
# indexed 669 documents
# indexed 670 documents
# indexed 671 documents
# indexed 672 documents
# indexed 673 documents
# indexed 674 documents
# indexed 675 documents
# indexed 676 documents
# indexed 677 documents
# indexed 678 documents
# indexed 679 documents
# indexed 680 documents
# indexed 681 documents
# indexed 682 documents
# indexed 683 documents
# indexed 684 documents
# indexed 685 documents
# indexed 686 documents
# indexed 687 documents
# indexed 688 documents
# indexed 689 documents
# indexed 690 documents
# indexed 691 documents
# indexed 692 documents
# indexed 693 documents
# indexed 694 documents
# indexed 695 documents
# indexed 696 documents
# indexed 697 documents
# indexed 698 documents
# indexed 699 documents
# indexed 700 documents
# indexed 701 documents
# indexed 702 documents
# indexed 703 documents
# indexed 704 documents
# indexed 705 documents
# indexed 706 documents
# indexed 707 documents
# indexed 708 documents
# indexed 709 documents
# indexed 710 documents
# indexed 711 documents
# indexed 712 documents
# indexed 713 documents
# indexed 714 documents
# indexed 715 documents
# indexed 716 documents
# indexed 717 documents
# indexed 718 documents
# indexed 719 documents
# indexed 720 documents
# indexed 721 documents
# indexed 722 documents
# indexed 723 documents
# indexed 724 documents
# indexed 725 documents
# indexed 726 documents
# indexed 727 documents
# indexed 728 documents
# indexed 729 documents
# indexed 730 documents
# indexed 731 documents
# indexed 732 documents
# indexed 733 documents
# indexed 734 documents
# indexed 735 documents
# indexed 736 documents
# indexed 737 documents
# indexed 738 documents
# indexed 739 documents
# indexed 740 documents
# indexed 741 documents
# indexed 742 documents
# indexed 743 documents
# indexed 744 documents
# indexed 745 documents
# indexed 746 documents
# indexed 747 documents
# indexed 748 documents
# indexed 749 documents
# indexed 750 documents
# indexed 751 documents
# indexed 752 documents
# indexed 753 documents
# indexed 754 documents
# indexed 755 documents
# indexed 756 documents
# indexed 757 documents
# indexed 758 documents
# indexed 759 documents
# indexed 760 documents
# indexed 761 documents
# indexed 762 documents
# indexed 763 documents
# indexed 764 documents
# indexed 765 documents
# indexed 766 documents
# indexed 767 documents
# indexed 768 documents
# indexed 769 documents
# indexed 770 documents
# indexed 771 documents
# indexed 772 documents
# indexed 773 documents
# indexed 774 documents
# indexed 775 documents
# indexed 776 documents
# indexed 777 documents
# indexed 778 documents
# indexed 779 documents
# indexed 780 documents
# indexed 781 documents
# indexed 782 documents
# indexed 783 documents
# indexed 784 documents
# indexed 785 documents
# indexed 786 documents
# indexed 787 documents
# indexed 788 documents
# indexed 789 documents
# indexed 790 documents
# indexed 791 documents
# indexed 792 documents
# indexed 793 documents
# indexed 794 documents
# indexed 795 documents
# indexed 796 documents
# indexed 797 documents
# indexed 798 documents
# indexed 799 documents
# indexed 800 documents
# indexed 801 documents
# indexed 802 documents
# indexed 803 documents
# indexed 804 documents
# indexed 805 documents
# indexed 806 documents
# indexed 807 documents
# indexed 808 documents
# indexed 809 documents
# indexed 810 documents
# indexed 811 documents
# indexed 812 documents
# indexed 813 documents
# indexed 814 documents
# indexed 815 documents
# indexed 816 documents
# indexed 817 documents
# indexed 818 documents
# indexed 819 documents
# indexed 820 documents
# indexed 821 documents
# indexed 822 documents
# indexed 823 documents
# indexed 824 documents
# indexed 825 documents
# indexed 826 documents
# indexed 827 documents
# indexed 828 documents
# indexed 829 documents
# indexed 830 documents
# indexed 831 documents
# indexed 832 documents
# indexed 833 documents
# indexed 834 documents
# indexed 835 documents
# indexed 836 documents
# indexed 837 documents
# indexed 838 documents
# indexed 839 documents
# indexed 840 documents
# indexed 841 documents
# indexed 842 documents
# indexed 843 documents
# indexed 844 documents
# indexed 845 documents
# indexed 846 documents
# indexed 847 documents
# indexed 848 documents
# indexed 849 documents
# indexed 850 documents
# indexed 851 documents
# indexed 852 documents
# indexed 853 documents
# indexed 854 documents
# indexed 855 documents
# indexed 856 documents
# indexed 857 documents
# indexed 858 documents
# indexed 859 documents
# indexed 860 documents
# indexed 861 documents
# indexed 862 documents
# indexed 863 documents
# indexed 864 documents
# indexed 865 documents
# indexed 866 documents
# indexed 867 documents
# indexed 868 documents
# indexed 869 documents
# indexed 870 documents
# indexed 871 documents
# indexed 872 documents
# indexed 873 documents
# indexed 874 documents
# indexed 875 documents
# indexed 876 documents
# indexed 877 documents
# indexed 878 documents
# indexed 879 documents
# indexed 880 documents
# indexed 881 documents
# indexed 882 documents
# indexed 883 documents
# indexed 884 documents
# indexed 885 documents
# indexed 886 documents
# indexed 887 documents
# indexed 888 documents
# indexed 889 documents
# indexed 890 documents
# indexed 891 documents
# indexed 892 documents
# indexed 893 documents
# indexed 894 documents
# indexed 895 documents
# indexed 896 documents
# indexed 897 documents
# indexed 898 documents
# indexed 899 documents
# indexed 900 documents
# indexed 901 documents
# indexed 902 documents
# indexed 903 documents
# indexed 904 documents
# indexed 905 documents
# indexed 906 documents
# indexed 907 documents
# indexed 908 documents
# indexed 909 documents
# indexed 910 documents
# indexed 911 documents
# indexed 912 documents
# indexed 913 documents
# indexed 914 documents
# indexed 915 documents
# indexed 916 documents
# indexed 917 documents
# indexed 918 documents
# indexed 919 documents
# indexed 920 documents
# indexed 921 documents
# indexed 922 documents
# indexed 923 documents
# indexed 924 documents
# indexed 925 documents
# indexed 926 documents
# indexed 927 documents
# indexed 928 documents
# indexed 929 documents
# indexed 930 documents
# indexed 931 documents
# indexed 932 documents
# indexed 933 documents
# indexed 934 documents
# indexed 935 documents
# indexed 936 documents
# indexed 937 documents
# indexed 938 documents
# indexed 939 documents
# indexed 940 documents
# indexed 941 documents
# indexed 942 documents
# indexed 943 documents
# indexed 944 documents
# indexed 945 documents
# indexed 946 documents
# indexed 947 documents
# indexed 948 documents
# indexed 949 documents
# indexed 950 documents
# indexed 951 documents
# indexed 952 documents
# indexed 953 documents
# indexed 954 documents
# indexed 955 documents
# indexed 956 documents
# indexed 957 documents
# indexed 958 documents
# indexed 959 documents
# indexed 960 documents
# indexed 961 documents
# indexed 962 documents
# indexed 963 documents
# indexed 964 documents
# indexed 965 documents
# indexed 966 documents
# indexed 967 documents
# indexed 968 documents
# indexed 969 documents
# indexed 970 documents
# indexed 971 documents
# indexed 972 documents
# indexed 973 documents
# indexed 974 documents
# indexed 975 documents
# indexed 976 documents
# indexed 977 documents
# indexed 978 documents
# indexed 979 documents
# indexed 980 documents
# indexed 981 documents
# indexed 982 documents
# indexed 983 documents
# indexed 984 documents
# indexed 985 documents
# indexed 986 documents
# indexed 987 documents
# indexed 988 documents
# indexed 989 documents
# indexed 990 documents
# indexed 991 documents
# indexed 992 documents
# indexed 993 documents
# indexed 994 documents
# indexed 995 documents
# indexed 996 documents
# indexed 997 documents
# indexed 998 documents
# indexed 999 documents
# indexed 1000 documents
# indexed 1001 documents
# indexed 1002 documents
# indexed 1003 documents
# indexed 1004 documents
# indexed 1005 documents
# indexed 1006 documents
# indexed 1007 documents
# indexed 1008 documents
# indexed 1009 documents
# indexed 1010 documents
# indexed 1011 documents
# indexed 1012 documents
# indexed 1013 documents
# indexed 1014 documents
# indexed 1015 documents
# indexed 1016 documents
# indexed 1017 documents
# indexed 1018 documents
# indexed 1019 documents
# indexed 1020 documents
# indexed 1021 documents
# indexed 1022 documents
# indexed 1023 documents
# indexed 1024 documents
# indexed 1025 documents
# indexed 1026 documents
# indexed 1027 documents
# indexed 1028 documents
# indexed 1029 documents
# indexed 1030 documents
# indexed 1031 documents
# indexed 1032 documents
# indexed 1033 documents
# indexed 1034 documents
# indexed 1035 documents
# indexed 1036 documents
# indexed 1037 documents
# indexed 1038 documents
# indexed 1039 documents
# indexed 1040 documents
# indexed 1041 documents
# indexed 1042 documents
# indexed 1043 documents
# indexed 1044 documents
# indexed 1045 documents
# indexed 1046 documents
# indexed 1047 documents
# indexed 1048 documents
# indexed 1049 documents
# indexed 1050 documents
# indexed 1051 documents
# indexed 1052 documents
# indexed 1053 documents
# indexed 1054 documents
# indexed 1055 documents
# indexed 1056 documents
# indexed 1057 documents
# indexed 1058 documents
# indexed 1059 documents
# indexed 1060 documents
# indexed 1061 documents
# indexed 1062 documents
# indexed 1063 documents
# indexed 1064 documents
# indexed 1065 documents
# indexed 1066 documents
# indexed 1067 documents
# indexed 1068 documents
# indexed 1069 documents
# indexed 1070 documents
# indexed 1071 documents
# indexed 1072 documents
# indexed 1073 documents
# indexed 1074 documents
# indexed 1075 documents
# indexed 1076 documents
# indexed 1077 documents
# indexed 1078 documents
# indexed 1079 documents
# indexed 1080 documents
# indexed 1081 documents
# indexed 1082 documents
# indexed 1083 documents
# indexed 1084 documents
# indexed 1085 documents
# indexed 1086 documents
# indexed 1087 documents
# indexed 1088 documents
# indexed 1089 documents
# indexed 1090 documents
# indexed 1091 documents
# indexed 1092 documents
# indexed 1093 documents
# indexed 1094 documents
# indexed 1095 documents
# indexed 1096 documents
# indexed 1097 documents
# indexed 1098 documents
# indexed 1099 documents
# indexed 1100 documents
# indexed 1101 documents
# indexed 1102 documents
# indexed 1103 documents
# indexed 1104 documents
# indexed 1105 documents
# indexed 1106 documents
# indexed 1107 documents
# indexed 1108 documents
# indexed 1109 documents
# indexed 1110 documents
# indexed 1111 documents
# indexed 1112 documents
# indexed 1113 documents
# indexed 1114 documents
# indexed 1115 documents
# indexed 1116 documents
# indexed 1117 documents
# indexed 1118 documents
# indexed 1119 documents
# indexed 1120 documents
# indexed 1121 documents
# indexed 1122 documents
# indexed 1123 documents
# indexed 1124 documents
# indexed 1125 documents
# indexed 1126 documents
# indexed 1127 documents
# indexed 1128 documents
# indexed 1129 documents
# indexed 1130 documents
# indexed 1131 documents
# indexed 1132 documents
# indexed 1133 documents
# indexed 1134 documents
# indexed 1135 documents
# indexed 1136 documents
# indexed 1137 documents
# indexed 1138 documents
# indexed 1139 documents
# indexed 1140 documents
# indexed 1141 documents
# indexed 1142 documents
# indexed 1143 documents
# indexed 1144 documents
# indexed 1145 documents
# indexed 1146 documents
# indexed 1147 documents
# indexed 1148 documents
# indexed 1149 documents
# indexed 1150 documents
# indexed 1151 documents
# indexed 1152 documents
# indexed 1153 documents
# indexed 1154 documents
# indexed 1155 documents
# indexed 1156 documents
# indexed 1157 documents
# indexed 1158 documents
# indexed 1159 documents
# indexed 1160 documents
# indexed 1161 documents
# indexed 1162 documents
# indexed 1163 documents
# indexed 1164 documents
# indexed 1165 documents
# indexed 1166 documents
# indexed 1167 documents
# indexed 1168 documents
# indexed 1169 documents
# indexed 1170 documents
# indexed 1171 documents
# indexed 1172 documents
# indexed 1173 documents
# indexed 1174 documents
# indexed 1175 documents
# indexed 1176 documents
# indexed 1177 documents
# indexed 1178 documents
# indexed 1179 documents
# indexed 1180 documents
# indexed 1181 documents
# indexed 1182 documents
# indexed 1183 documents
# indexed 1184 documents
# indexed 1185 documents
# indexed 1186 documents
# indexed 1187 documents
# indexed 1188 documents
# indexed 1189 documents
# indexed 1190 documents
# indexed 1191 documents
# indexed 1192 documents
# indexed 1193 documents
# indexed 1194 documents
# indexed 1195 documents
# indexed 1196 documents
# indexed 1197 documents
# indexed 1198 documents
# indexed 1199 documents
# indexed 1200 documents
# indexed 1201 documents
# indexed 1202 documents
# indexed 1203 documents
# indexed 1204 documents
# indexed 1205 documents
# indexed 1206 documents
# indexed 1207 documents
# indexed 1208 documents
# indexed 1209 documents
# indexed 1210 documents
# indexed 1211 documents
# indexed 1212 documents
# indexed 1213 documents
# indexed 1214 documents
# indexed 1215 documents
# indexed 1216 documents
# indexed 1217 documents
# indexed 1218 documents
# indexed 1219 documents
# indexed 1220 documents
# indexed 1221 documents
# indexed 1222 documents
# indexed 1223 documents
# indexed 1224 documents
# indexed 1225 documents
# indexed 1226 documents
# indexed 1227 documents
# indexed 1228 documents
# indexed 1229 documents
# indexed 1230 documents
# indexed 1231 documents
# indexed 1232 documents
# indexed 1233 documents
# indexed 1234 documents
# indexed 1235 documents
# indexed 1236 documents
# indexed 1237 documents
# indexed 1238 documents
# indexed 1239 documents
# indexed 1240 documents
# indexed 1241 documents
# indexed 1242 documents
# indexed 1243 documents
# indexed 1244 documents
# indexed 1245 documents
# indexed 1246 documents
# indexed 1247 documents
# indexed 1248 documents
# indexed 1249 documents
# indexed 1250 documents
# indexed 1251 documents
# indexed 1252 documents
# indexed 1253 documents
# indexed 1254 documents
# indexed 1255 documents
# indexed 1256 documents
# indexed 1257 documents
# indexed 1258 documents
# indexed 1259 documents
# indexed 1260 documents
# indexed 1261 documents
# indexed 1262 documents
# indexed 1263 documents
# indexed 1264 documents
# indexed 1265 documents
# indexed 1266 documents
# indexed 1267 documents
# indexed 1268 documents
# indexed 1269 documents
# indexed 1270 documents
# indexed 1271 documents
# indexed 1272 documents
# indexed 1273 documents
# indexed 1274 documents
# indexed 1275 documents
# indexed 1276 documents
# indexed 1277 documents
# indexed 1278 documents
# indexed 1279 documents
# indexed 1280 documents
# indexed 1281 documents
# indexed 1282 documents
# indexed 1283 documents
# indexed 1284 documents
# indexed 1285 documents
# indexed 1286 documents
# indexed 1287 documents
# indexed 1288 documents
# indexed 1289 documents
# indexed 1290 documents
# indexed 1291 documents
# indexed 1292 documents
# indexed 1293 documents
# indexed 1294 documents
# indexed 1295 documents
# indexed 1296 documents
# indexed 1297 documents
# indexed 1298 documents
# indexed 1299 documents
# indexed 1300 documents
# indexed 1301 documents
# indexed 1302 documents
# indexed 1303 documents
# indexed 1304 documents
# indexed 1305 documents
# indexed 1306 documents
# indexed 1307 documents
# indexed 1308 documents
# indexed 1309 documents
# indexed 1310 documents
# indexed 1311 documents
# indexed 1312 documents
# indexed 1313 documents
# indexed 1314 documents
# indexed 1315 documents
# indexed 1316 documents
# indexed 1317 documents
# indexed 1318 documents
# indexed 1319 documents
# indexed 1320 documents
# indexed 1321 documents
# indexed 1322 documents
# indexed 1323 documents
# indexed 1324 documents
# indexed 1325 documents
# indexed 1326 documents
# indexed 1327 documents
# indexed 1328 documents
# indexed 1329 documents
# indexed 1330 documents
# indexed 1331 documents
# indexed 1332 documents
# indexed 1333 documents
# indexed 1334 documents
# indexed 1335 documents
# indexed 1336 documents
# indexed 1337 documents
# indexed 1338 documents
# indexed 1339 documents
# indexed 1340 documents
# indexed 1341 documents
# indexed 1342 documents
# indexed 1343 documents
# indexed 1344 documents
# indexed 1345 documents
# indexed 1346 documents
# indexed 1347 documents
# indexed 1348 documents
# indexed 1349 documents
# indexed 1350 documents
# indexed 1351 documents
# indexed 1352 documents
# indexed 1353 documents
# indexed 1354 documents
# indexed 1355 documents
# indexed 1356 documents
# indexed 1357 documents
# indexed 1358 documents
# indexed 1359 documents
# indexed 1360 documents
# indexed 1361 documents
# indexed 1362 documents
# indexed 1363 documents
# indexed 1364 documents
# indexed 1365 documents
# indexed 1366 documents
# indexed 1367 documents
# indexed 1368 documents
# indexed 1369 documents
# indexed 1370 documents
# indexed 1371 documents
# indexed 1372 documents
# indexed 1373 documents
# indexed 1374 documents
# indexed 1375 documents
# indexed 1376 documents
# indexed 1377 documents
# indexed 1378 documents
# indexed 1379 documents
# indexed 1380 documents
# indexed 1381 documents
# indexed 1382 documents
# indexed 1383 documents
# indexed 1384 documents
# indexed 1385 documents
# indexed 1386 documents
# indexed 1387 documents
# indexed 1388 documents
# indexed 1389 documents
# indexed 1390 documents
# indexed 1391 documents
# indexed 1392 documents
# indexed 1393 documents
# indexed 1394 documents
# indexed 1395 documents
# indexed 1396 documents
# indexed 1397 documents
# indexed 1398 documents
# indexed 1399 documents
# indexed 1400 documents
# indexed 1401 documents
# indexed 1402 documents
# indexed 1403 documents
# indexed 1404 documents
# indexed 1405 documents
# indexed 1406 documents
# indexed 1407 documents
# indexed 1408 documents
# indexed 1409 documents
# indexed 1410 documents
# indexed 1411 documents
# indexed 1412 documents
# indexed 1413 documents
# indexed 1414 documents
# indexed 1415 documents
# indexed 1416 documents
# indexed 1417 documents
# indexed 1418 documents
# indexed 1419 documents
# indexed 1420 documents
# indexed 1421 documents
# indexed 1422 documents
# indexed 1423 documents
# indexed 1424 documents
# indexed 1425 documents
# indexed 1426 documents
# indexed 1427 documents
# indexed 1428 documents
# indexed 1429 documents
# indexed 1430 documents
# indexed 1431 documents
# indexed 1432 documents
# indexed 1433 documents
# indexed 1434 documents
# indexed 1435 documents
# indexed 1436 documents
# indexed 1437 documents
# indexed 1438 documents
# indexed 1439 documents
# indexed 1440 documents
# indexed 1441 documents
# indexed 1442 documents
# indexed 1443 documents
# indexed 1444 documents
# indexed 1445 documents
# indexed 1446 documents
# indexed 1447 documents
# indexed 1448 documents
# indexed 1449 documents
# indexed 1450 documents
# indexed 1451 documents
# indexed 1452 documents
# indexed 1453 documents
# indexed 1454 documents
# indexed 1455 documents
# indexed 1456 documents
# indexed 1457 documents
# indexed 1458 documents
# indexed 1459 documents
# indexed 1460 documents
# indexed 1461 documents
# indexed 1462 documents
# indexed 1463 documents
# indexed 1464 documents
# indexed 1465 documents
# indexed 1466 documents
# indexed 1467 documents
# indexed 1468 documents
# indexed 1469 documents
# indexed 1470 documents
# indexed 1471 documents
# indexed 1472 documents
# indexed 1473 documents
# indexed 1474 documents
# indexed 1475 documents
# indexed 1476 documents
# indexed 1477 documents
# indexed 1478 documents
# indexed 1479 documents
# indexed 1480 documents
# indexed 1481 documents
# indexed 1482 documents
# indexed 1483 documents
# indexed 1484 documents
# indexed 1485 documents
# indexed 1486 documents
# indexed 1487 documents
# indexed 1488 documents
# indexed 1489 documents
# indexed 1490 documents
# indexed 1491 documents
# indexed 1492 documents
# indexed 1493 documents
# indexed 1494 documents
# indexed 1495 documents
# indexed 1496 documents
# indexed 1497 documents
# indexed 1498 documents
# indexed 1499 documents
# indexed 1500 documents
# indexed 1501 documents
# indexed 1502 documents
# indexed 1503 documents
# indexed 1504 documents
# indexed 1505 documents
# indexed 1506 documents
# indexed 1507 documents
# indexed 1508 documents
# indexed 1509 documents
# indexed 1510 documents
# indexed 1511 documents
# indexed 1512 documents
# indexed 1513 documents
# indexed 1514 documents
# indexed 1515 documents
# indexed 1516 documents
# indexed 1517 documents
# indexed 1518 documents
# indexed 1519 documents
# indexed 1520 documents
# indexed 1521 documents
# indexed 1522 documents
# indexed 1523 documents
# indexed 1524 documents
# indexed 1525 documents
# indexed 1526 documents
# indexed 1527 documents
# indexed 1528 documents
# indexed 1529 documents
# indexed 1530 documents
# indexed 1531 documents
# indexed 1532 documents
# indexed 1533 documents
# indexed 1534 documents
# indexed 1535 documents
# indexed 1536 documents
# indexed 1537 documents
# indexed 1538 documents
# indexed 1539 documents
# indexed 1540 documents
# indexed 1541 documents
# indexed 1542 documents
# indexed 1543 documents
# indexed 1544 documents
# indexed 1545 documents
# indexed 1546 documents
# indexed 1547 documents
# indexed 1548 documents
# indexed 1549 documents
# indexed 1550 documents
# indexed 1551 documents
# indexed 1552 documents
# indexed 1553 documents
# indexed 1554 documents
# indexed 1555 documents
# indexed 1556 documents
# indexed 1557 documents
# indexed 1558 documents
# indexed 1559 documents
# indexed 1560 documents
# indexed 1561 documents
# indexed 1562 documents
# indexed 1563 documents
# indexed 1564 documents
# indexed 1565 documents
# indexed 1566 documents
# indexed 1567 documents
# indexed 1568 documents
# indexed 1569 documents
# indexed 1570 documents
# indexed 1571 documents
# indexed 1572 documents
# indexed 1573 documents
# indexed 1574 documents
# indexed 1575 documents
# indexed 1576 documents
# indexed 1577 documents
# indexed 1578 documents
# indexed 1579 documents
# indexed 1580 documents
# indexed 1581 documents
# indexed 1582 documents
# indexed 1583 documents
# indexed 1584 documents
# indexed 1585 documents
# indexed 1586 documents
# indexed 1587 documents
# indexed 1588 documents
# indexed 1589 documents
# indexed 1590 documents
# indexed 1591 documents
# indexed 1592 documents
# indexed 1593 documents
# indexed 1594 documents
# indexed 1595 documents
# indexed 1596 documents
# indexed 1597 documents
# indexed 1598 documents
# indexed 1599 documents
# indexed 1600 documents
# indexed 1601 documents
# indexed 1602 documents
# indexed 1603 documents
# indexed 1604 documents
# indexed 1605 documents
# indexed 1606 documents
# indexed 1607 documents
# indexed 1608 documents
# indexed 1609 documents
# indexed 1610 documents
# indexed 1611 documents
# indexed 1612 documents
# indexed 1613 documents
# indexed 1614 documents
# indexed 1615 documents
# indexed 1616 documents
# indexed 1617 documents
# indexed 1618 documents
# indexed 1619 documents
# indexed 1620 documents
# indexed 1621 documents
# indexed 1622 documents
# indexed 1623 documents
# indexed 1624 documents
# indexed 1625 documents
# indexed 1626 documents
# indexed 1627 documents
# indexed 1628 documents
# indexed 1629 documents
# indexed 1630 documents
# indexed 1631 documents
# indexed 1632 documents
# indexed 1633 documents
# indexed 1634 documents
# indexed 1635 documents
# indexed 1636 documents
# indexed 1637 documents
# indexed 1638 documents
# indexed 1639 documents
# indexed 1640 documents
# indexed 1641 documents
# indexed 1642 documents
# indexed 1643 documents
# indexed 1644 documents
# indexed 1645 documents
# indexed 1646 documents
# indexed 1647 documents
# indexed 1648 documents
# indexed 1649 documents
# indexed 1650 documents
# indexed 1651 documents
# indexed 1652 documents
# indexed 1653 documents
# indexed 1654 documents
# indexed 1655 documents
# indexed 1656 documents
# indexed 1657 documents
# indexed 1658 documents
# indexed 1659 documents
# indexed 1660 documents
# indexed 1661 documents
# indexed 1662 documents
# indexed 1663 documents
# indexed 1664 documents
# indexed 1665 documents
# indexed 1666 documents
# indexed 1667 documents
# indexed 1668 documents
# indexed 1669 documents
# indexed 1670 documents
# indexed 1671 documents
# indexed 1672 documents
# indexed 1673 documents
# indexed 1674 documents
# indexed 1675 documents
# indexed 1676 documents
# indexed 1677 documents
# indexed 1678 documents
# indexed 1679 documents
# indexed 1680 documents
# indexed 1681 documents
# indexed 1682 documents
# indexed 1683 documents
# indexed 1684 documents
# indexed 1685 documents
# indexed 1686 documents
# indexed 1687 documents
# indexed 1688 documents
# indexed 1689 documents
# indexed 1690 documents
# indexed 1691 documents
# indexed 1692 documents
# indexed 1693 documents
# indexed 1694 documents
# indexed 1695 documents
# indexed 1696 documents
# indexed 1697 documents
# indexed 1698 documents
# indexed 1699 documents
# indexed 1700 documents
# indexed 1701 documents
# indexed 1702 documents
# indexed 1703 documents
# indexed 1704 documents
# indexed 1705 documents
# indexed 1706 documents
# indexed 1707 documents
# indexed 1708 documents
# indexed 1709 documents
# indexed 1710 documents
# indexed 1711 documents
# indexed 1712 documents
# indexed 1713 documents
# indexed 1714 documents
# indexed 1715 documents
# indexed 1716 documents
# indexed 1717 documents
# indexed 1718 documents
# indexed 1719 documents
# indexed 1720 documents
# indexed 1721 documents
# indexed 1722 documents
# indexed 1723 documents
# indexed 1724 documents
# indexed 1725 documents
# indexed 1726 documents
# indexed 1727 documents
# indexed 1728 documents
# indexed 1729 documents
# indexed 1730 documents
# indexed 1731 documents
# indexed 1732 documents
# indexed 1733 documents
# indexed 1734 documents
# indexed 1735 documents
# indexed 1736 documents
# indexed 1737 documents
# indexed 1738 documents
# indexed 1739 documents
# indexed 1740 documents
# indexed 1741 documents
# indexed 1742 documents
# indexed 1743 documents
# indexed 1744 documents
# indexed 1745 documents
# indexed 1746 documents
# indexed 1747 documents
# indexed 1748 documents
# indexed 1749 documents
# indexed 1750 documents
# indexed 1751 documents
# indexed 1752 documents
# indexed 1753 documents
# indexed 1754 documents
# indexed 1755 documents
# indexed 1756 documents
# indexed 1757 documents
# indexed 1758 documents
# indexed 1759 documents
# indexed 1760 documents
# indexed 1761 documents
# indexed 1762 documents
# indexed 1763 documents
# indexed 1764 documents
# indexed 1765 documents
# indexed 1766 documents
# indexed 1767 documents
# indexed 1768 documents
# indexed 1769 documents
# indexed 1770 documents
# indexed 1771 documents
# indexed 1772 documents
# indexed 1773 documents
# indexed 1774 documents
# indexed 1775 documents
# indexed 1776 documents
# indexed 1777 documents
# indexed 1778 documents
# indexed 1779 documents
# indexed 1780 documents
# indexed 1781 documents
# indexed 1782 documents
# indexed 1783 documents
# indexed 1784 documents
# indexed 1785 documents
# indexed 1786 documents
# indexed 1787 documents
# indexed 1788 documents
# indexed 1789 documents
# indexed 1790 documents
# indexed 1791 documents
# indexed 1792 documents
# indexed 1793 documents
# indexed 1794 documents
# indexed 1795 documents
# indexed 1796 documents
# indexed 1797 documents
# indexed 1798 documents
# indexed 1799 documents
# indexed 1800 documents
# indexed 1801 documents
# indexed 1802 documents
# indexed 1803 documents
# indexed 1804 documents
# indexed 1805 documents
# indexed 1806 documents
# indexed 1807 documents
# indexed 1808 documents
# indexed 1809 documents
# indexed 1810 documents
# indexed 1811 documents
# indexed 1812 documents
# indexed 1813 documents
# indexed 1814 documents
# indexed 1815 documents
# indexed 1816 documents
# indexed 1817 documents
# indexed 1818 documents
# indexed 1819 documents
# indexed 1820 documents
# indexed 1821 documents
# indexed 1822 documents
# indexed 1823 documents
# indexed 1824 documents
# indexed 1825 documents
# indexed 1826 documents
# indexed 1827 documents
# indexed 1828 documents
# indexed 1829 documents
# indexed 1830 documents
# indexed 1831 documents
# indexed 1832 documents
# indexed 1833 documents
# indexed 1834 documents
# indexed 1835 documents
# indexed 1836 documents
# indexed 1837 documents
# indexed 1838 documents
# indexed 1839 documents
# indexed 1840 documents
# indexed 1841 documents
# indexed 1842 documents
# indexed 1843 documents
# indexed 1844 documents
# indexed 1845 documents
# indexed 1846 documents
# indexed 1847 documents
# indexed 1848 documents
# indexed 1849 documents
# indexed 1850 documents
# indexed 1851 documents
# indexed 1852 documents
# indexed 1853 documents
# indexed 1854 documents
# indexed 1855 documents
# indexed 1856 documents
# indexed 1857 documents
# indexed 1858 documents
# indexed 1859 documents
# indexed 1860 documents
# indexed 1861 documents
# indexed 1862 documents
# indexed 1863 documents
# indexed 1864 documents
# indexed 1865 documents
# indexed 1866 documents
# indexed 1867 documents
# indexed 1868 documents
# indexed 1869 documents
# indexed 1870 documents
# indexed 1871 documents
# indexed 1872 documents
# indexed 1873 documents
# indexed 1874 documents
# indexed 1875 documents
# indexed 1876 documents
# indexed 1877 documents
# indexed 1878 documents
# indexed 1879 documents
# indexed 1880 documents
# indexed 1881 documents
# indexed 1882 documents
# indexed 1883 documents
# indexed 1884 documents
# indexed 1885 documents
# indexed 1886 documents
# indexed 1887 documents
# indexed 1888 documents
# indexed 1889 documents
# indexed 1890 documents
# indexed 1891 documents
# indexed 1892 documents
# indexed 1893 documents
# indexed 1894 documents
# indexed 1895 documents
# indexed 1896 documents
# indexed 1897 documents
# indexed 1898 documents
# indexed 1899 documents
# indexed 1900 documents
# indexed 1901 documents
# indexed 1902 documents
# indexed 1903 documents
# indexed 1904 documents
# indexed 1905 documents
# indexed 1906 documents
# indexed 1907 documents
# indexed 1908 documents
# indexed 1909 documents
# indexed 1910 documents
# indexed 1911 documents
# indexed 1912 documents
# indexed 1913 documents
# indexed 1914 documents
# indexed 1915 documents
# indexed 1916 documents
# indexed 1917 documents
# indexed 1918 documents
# indexed 1919 documents
# indexed 1920 documents
# indexed 1921 documents
# indexed 1922 documents
# indexed 1923 documents
# indexed 1924 documents
# indexed 1925 documents
# indexed 1926 documents
# indexed 1927 documents
# indexed 1928 documents
# indexed 1929 documents
# indexed 1930 documents
# indexed 1931 documents
# indexed 1932 documents
# indexed 1933 documents
# indexed 1934 documents
# indexed 1935 documents
# indexed 1936 documents
# indexed 1937 documents
# indexed 1938 documents
# indexed 1939 documents
# indexed 1940 documents
# indexed 1941 documents
# indexed 1942 documents
# indexed 1943 documents
# indexed 1944 documents
# indexed 1945 documents
# indexed 1946 documents
# indexed 1947 documents
# indexed 1948 documents
# indexed 1949 documents
# indexed 1950 documents
# indexed 1951 documents
# indexed 1952 documents
# indexed 1953 documents
# indexed 1954 documents
# indexed 1955 documents
# indexed 1956 documents
# indexed 1957 documents
# indexed 1958 documents
# indexed 1959 documents
# indexed 1960 documents
# indexed 1961 documents
# indexed 1962 documents
# indexed 1963 documents
# indexed 1964 documents
# indexed 1965 documents
# indexed 1966 documents
# indexed 1967 documents
# indexed 1968 documents
# indexed 1969 documents
# indexed 1970 documents
# indexed 1971 documents
# indexed 1972 documents
# indexed 1973 documents
# indexed 1974 documents
# indexed 1975 documents
# indexed 1976 documents
# indexed 1977 documents
# indexed 1978 documents
# indexed 1979 documents
# indexed 1980 documents
# indexed 1981 documents
# indexed 1982 documents
# indexed 1983 documents
# indexed 1984 documents
# indexed 1985 documents
# indexed 1986 documents
# indexed 1987 documents
# indexed 1988 documents
# indexed 1989 documents
# indexed 1990 documents
# indexed 1991 documents
# indexed 1992 documents
# indexed 1993 documents
# indexed 1994 documents
# indexed 1995 documents
# indexed 1996 documents
# indexed 1997 documents
# indexed 1998 documents
# indexed 1999 documents
# indexed 2000 documents
# indexed 2001 documents
# indexed 2002 documents
# indexed 2003 documents
# indexed 2004 documents
# indexed 2005 documents
# indexed 2006 documents
# indexed 2007 documents
# indexed 2008 documents
# indexed 2009 documents
# indexed 2010 documents
# indexed 2011 documents
# indexed 2012 documents
# indexed 2013 documents
# indexed 2014 documents
# indexed 2015 documents
# indexed 2016 documents
# indexed 2017 documents
# indexed 2018 documents
# indexed 2019 documents
# indexed 2020 documents
# indexed 2021 documents
# indexed 2022 documents
# indexed 2023 documents
# indexed 2024 documents
# indexed 2025 documents
# indexed 2026 documents
# indexed 2027 documents
# indexed 2028 documents
# indexed 2029 documents
# indexed 2030 documents
# indexed 2031 documents
# indexed 2032 documents
# indexed 2033 documents
# indexed 2034 documents
# indexed 2035 documents
# indexed 2036 documents
# indexed 2037 documents
# indexed 2038 documents
# indexed 2039 documents
# indexed 2040 documents
# indexed 2041 documents
# indexed 2042 documents
# indexed 2043 documents
# indexed 2044 documents
# indexed 2045 documents
# indexed 2046 documents
# indexed 2047 documents
# indexed 2048 documents
# indexed 2049 documents
# indexed 2050 documents
# indexed 2051 documents
# indexed 2052 documents
# indexed 2053 documents
# indexed 2054 documents
# indexed 2055 documents
# indexed 2056 documents
# indexed 2057 documents
# indexed 2058 documents
# indexed 2059 documents
# indexed 2060 documents
# indexed 2061 documents
# indexed 2062 documents
# indexed 2063 documents
# indexed 2064 documents
# indexed 2065 documents
# indexed 2066 documents
# indexed 2067 documents
# indexed 2068 documents
# indexed 2069 documents
# indexed 2070 documents
# indexed 2071 documents
# indexed 2072 documents
# indexed 2073 documents
# indexed 2074 documents
# indexed 2075 documents
# indexed 2076 documents
# indexed 2077 documents
# indexed 2078 documents
# indexed 2079 documents
# indexed 2080 documents
# indexed 2081 documents
# indexed 2082 documents
# indexed 2083 documents
# indexed 2084 documents
# indexed 2085 documents
# indexed 2086 documents
# indexed 2087 documents
# indexed 2088 documents
# indexed 2089 documents
# indexed 2090 documents
# indexed 2091 documents
# indexed 2092 documents
# indexed 2093 documents
# indexed 2094 documents
# indexed 2095 documents
# indexed 2096 documents
# indexed 2097 documents
# indexed 2098 documents
# indexed 2099 documents
# indexed 2100 documents
# indexed 2101 documents
# indexed 2102 documents
# indexed 2103 documents
# indexed 2104 documents
# indexed 2105 documents
# indexed 2106 documents
# indexed 2107 documents
# indexed 2108 documents
# indexed 2109 documents
# indexed 2110 documents
# indexed 2111 documents
# indexed 2112 documents
# indexed 2113 documents
# indexed 2114 documents
# indexed 2115 documents
# indexed 2116 documents
# indexed 2117 documents
# indexed 2118 documents
# indexed 2119 documents
# indexed 2120 documents
# indexed 2121 documents
# indexed 2122 documents
# indexed 2123 documents
# indexed 2124 documents
# indexed 2125 documents
# indexed 2126 documents
# indexed 2127 documents
# indexed 2128 documents
# indexed 2129 documents
# indexed 2130 documents
# indexed 2131 documents
# indexed 2132 documents
# ...
# indexed 3388 documents
# indexed 3389 documents
# indexed 3390 documents
# indexed 3391 documents
# indexed 3392 documents
# indexed 3393 documents
# indexed 3394 documents
# indexed 3395 documents
# indexed 3396 documents
# indexed 3397 documents
# indexed 3398 documents
# indexed 3399 documents
# indexed 3400 documents
# indexed 3401 documents
# indexed 3402 documents
# indexed 3403 documents
# indexed 3404 documents
# indexed 3405 documents
# indexed 3406 documents
# indexed 3407 documents
# indexed 3408 documents
# indexed 3409 documents
# indexed 3410 documents
# indexed 3411 documents
# indexed 3412 documents
# indexed 3413 documents
# indexed 3414 documents
# indexed 3415 documents
# indexed 3416 documents
# indexed 3417 documents
# indexed 3418 documents
# indexed 3419 documents
# indexed 3420 documents
# indexed 3421 documents
# indexed 3422 documents
# indexed 3423 documents
# indexed 3424 documents
# indexed 3425 documents
# indexed 3426 documents
# indexed 3427 documents
# indexed 3428 documents
# indexed 3429 documents
# indexed 3430 documents
# indexed 3431 documents
# indexed 3432 documents
# indexed 3433 documents
# indexed 3434 documents
# indexed 3435 documents
# indexed 3436 documents
# indexed 3437 documents
# indexed 3438 documents
# indexed 3439 documents
# indexed 3440 documents
# indexed 3441 documents
# indexed 3442 documents
# indexed 3443 documents
# indexed 3444 documents
# indexed 3445 documents
# indexed 3446 documents
# indexed 3447 documents
# indexed 3448 documents
# indexed 3449 documents
# indexed 3450 documents
# indexed 3451 documents
# indexed 3452 documents
# indexed 3453 documents
# indexed 3454 documents
# indexed 3455 documents
# indexed 3456 documents
# indexed 3457 documents
# indexed 3458 documents
# indexed 3459 documents
# indexed 3460 documents
# indexed 3461 documents
# indexed 3462 documents
# indexed 3463 documents
# indexed 3464 documents
# indexed 3465 documents
# indexed 3466 documents
# indexed 3467 documents
# indexed 3468 documents
# indexed 3469 documents
# indexed 3470 documents
# indexed 3471 documents
# indexed 3472 documents
# indexed 3473 documents
# indexed 3474 documents
# indexed 3475 documents
# indexed 3476 documents
# indexed 3477 documents
# indexed 3478 documents
# indexed 3479 documents
# indexed 3480 documents
# indexed 3481 documents
# indexed 3482 documents
# indexed 3483 documents
# indexed 3484 documents
# indexed 3485 documents
# indexed 3486 documents
# indexed 3487 documents
# indexed 3488 documents
# indexed 3489 documents
# indexed 3490 documents
# indexed 3491 documents
# indexed 3492 documents
# indexed 3493 documents
# indexed 3494 documents
# indexed 3495 documents
# indexed 3496 documents
# indexed 3497 documents
# indexed 3498 documents
# indexed 3499 documents
# indexed 3500 documents
# indexed 3501 documents
# indexed 3502 documents
# indexed 3503 documents
# indexed 3504 documents
# indexed 3505 documents
# indexed 3506 documents
# indexed 3507 documents
# indexed 3508 documents
# indexed 3509 documents
# indexed 3510 documents
# indexed 3511 documents
# indexed 3512 documents
# indexed 3513 documents
# indexed 3514 documents
# indexed 3515 documents
# indexed 3516 documents
# indexed 3517 documents
# indexed 3518 documents
# indexed 3519 documents
# indexed 3520 documents
# indexed 3521 documents
# indexed 3522 documents
# indexed 3523 documents
# indexed 3524 documents
# indexed 3525 documents
# indexed 3526 documents
# indexed 3527 documents
# indexed 3528 documents
# indexed 3529 documents
# indexed 3530 documents
# indexed 3531 documents
# indexed 3532 documents
# indexed 3533 documents
# indexed 3534 documents
# indexed 3535 documents
# indexed 3536 documents
# indexed 3537 documents
# indexed 3538 documents
# indexed 3539 documents
# indexed 3540 documents
# indexed 3541 documents
# indexed 3542 documents
# indexed 3543 documents
# indexed 3544 documents
# indexed 3545 documents
# indexed 3546 documents
# indexed 3547 documents
# indexed 3548 documents
# indexed 3549 documents
# indexed 3550 documents
# indexed 3551 documents
# indexed 3552 documents
# indexed 3553 documents
# indexed 3554 documents
# indexed 3555 documents
# indexed 3556 documents
# indexed 3557 documents
# indexed 3558 documents
# indexed 3559 documents
# indexed 3560 documents
# indexed 3561 documents
# indexed 3562 documents
# indexed 3563 documents
# indexed 3564 documents
# indexed 3565 documents
# indexed 3566 documents
# indexed 3567 documents
# indexed 3568 documents
# indexed 3569 documents
# indexed 3570 documents
# indexed 3571 documents
# indexed 3572 documents
# indexed 3573 documents
# indexed 3574 documents
# indexed 3575 documents
# indexed 3576 documents
# indexed 3577 documents
# indexed 3578 documents
# indexed 3579 documents
# indexed 3580 documents
# indexed 3581 documents
# indexed 3582 documents
# indexed 3583 documents
# indexed 3584 documents
# indexed 3585 documents
# indexed 3586 documents
# indexed 3587 documents
# indexed 3588 documents
# indexed 3589 documents
# indexed 3590 documents
# indexed 3591 documents
# indexed 3592 documents
# indexed 3593 documents
# indexed 3594 documents
# indexed 3595 documents
# indexed 3596 documents
# indexed 3597 documents
# indexed 3598 documents
# indexed 3599 documents
# indexed 3600 documents
# indexed 3601 documents
# indexed 3602 documents
# indexed 3603 documents
# indexed 3604 documents
# indexed 3605 documents
# indexed 3606 documents
# indexed 3607 documents
# indexed 3608 documents
# indexed 3609 documents
# indexed 3610 documents
# indexed 3611 documents
# indexed 3612 documents
# indexed 3613 documents
# indexed 3614 documents
# indexed 3615 documents
# indexed 3616 documents
# indexed 3617 documents
# indexed 3618 documents
# indexed 3619 documents
# indexed 3620 documents
# indexed 3621 documents
# indexed 3622 documents
# indexed 3623 documents
# indexed 3624 documents
# indexed 3625 documents
# indexed 3626 documents
# indexed 3627 documents
# indexed 3628 documents
# indexed 3629 documents
# indexed 3630 documents
# indexed 3631 documents
# indexed 3632 documents
# indexed 3633 documents
# indexed 3634 documents
# indexed 3635 documents
# indexed 3636 documents
# indexed 3637 documents
# indexed 3638 documents
# indexed 3639 documents
# indexed 3640 documents
# indexed 3641 documents
# indexed 3642 documents
# indexed 3643 documents
# indexed 3644 documents
# indexed 3645 documents
# indexed 3646 documents
# indexed 3647 documents
# indexed 3648 documents
# indexed 3649 documents
# indexed 3650 documents
# indexed 3651 documents
# indexed 3652 documents
# indexed 3653 documents
# indexed 3654 documents
# indexed 3655 documents
# indexed 3656 documents
# indexed 3657 documents
# indexed 3658 documents
# indexed 3659 documents
# indexed 3660 documents
# indexed 3661 documents
# indexed 3662 documents
# indexed 3663 documents
# indexed 3664 documents
# indexed 3665 documents
# indexed 3666 documents
# indexed 3667 documents
# indexed 3668 documents
# indexed 3669 documents
# indexed 3670 documents
# indexed 3671 documents
# indexed 3672 documents
# indexed 3673 documents
# indexed 3674 documents
# indexed 3675 documents
# indexed 3676 documents
# indexed 3677 documents
# indexed 3678 documents
# indexed 3679 documents
# indexed 3680 documents
# indexed 3681 documents
# indexed 3682 documents
# indexed 3683 documents
# indexed 3684 documents
# indexed 3685 documents
# indexed 3686 documents
# indexed 3687 documents
# indexed 3688 documents
# indexed 3689 documents
# indexed 3690 documents
# indexed 3691 documents
# indexed 3692 documents
# indexed 3693 documents
# indexed 3694 documents
# indexed 3695 documents
# indexed 3696 documents
# indexed 3697 documents
# indexed 3698 documents
# indexed 3699 documents
# indexed 3700 documents
# indexed 3701 documents
# indexed 3702 documents
# indexed 3703 documents
# indexed 3704 documents
# indexed 3705 documents
# indexed 3706 documents
# indexed 3707 documents
# indexed 3708 documents
# indexed 3709 documents
# indexed 3710 documents
# indexed 3711 documents
# indexed 3712 documents
# indexed 3713 documents
# indexed 3714 documents
# indexed 3715 documents
# indexed 3716 documents
# indexed 3717 documents
# indexed 3718 documents
# indexed 3719 documents
# indexed 3720 documents
# indexed 3721 documents
# indexed 3722 documents
# indexed 3723 documents
# indexed 3724 documents
# indexed 3725 documents
# indexed 3726 documents
# indexed 3727 documents
# indexed 3728 documents
# indexed 3729 documents
# indexed 3730 documents
# indexed 3731 documents
# indexed 3732 documents
# indexed 3733 documents
# indexed 3734 documents
# indexed 3735 documents
# indexed 3736 documents
# indexed 3737 documents
# indexed 3738 documents
# indexed 3739 documents
# indexed 3740 documents
# indexed 3741 documents
# indexed 3742 documents
# indexed 3743 documents
# indexed 3744 documents
# indexed 3745 documents
# indexed 3746 documents
# indexed 3747 documents
# indexed 3748 documents
# indexed 3749 documents
# indexed 3750 documents
# indexed 3751 documents
# indexed 3752 documents
# indexed 3753 documents
# indexed 3754 documents
# indexed 3755 documents
# indexed 3756 documents
# indexed 3757 documents
# indexed 3758 documents
# indexed 3759 documents
# indexed 3760 documents
# indexed 3761 documents
# indexed 3762 documents
# indexed 3763 documents
# indexed 3764 documents
# indexed 3765 documents
# indexed 3766 documents
# indexed 3767 documents
# indexed 3768 documents
# indexed 3769 documents
# indexed 3770 documents
# indexed 3771 documents
# indexed 3772 documents
# indexed 3773 documents
# indexed 3774 documents
# indexed 3775 documents
# indexed 3776 documents
# indexed 3777 documents
# indexed 3778 documents
# indexed 3779 documents
# indexed 3780 documents
# indexed 3781 documents
# indexed 3782 documents
# indexed 3783 documents
# indexed 3784 documents
# indexed 3785 documents
# indexed 3786 documents
# indexed 3787 documents
# indexed 3788 documents
# indexed 3789 documents
# indexed 3790 documents
# indexed 3791 documents
# indexed 3792 documents
# indexed 3793 documents
# indexed 3794 documents
# indexed 3795 documents
# indexed 3796 documents
# indexed 3797 documents
# indexed 3798 documents
# indexed 3799 documents
# indexed 3800 documents
# indexed 3801 documents
# indexed 3802 documents
# indexed 3803 documents
# indexed 3804 documents
# indexed 3805 documents
# indexed 3806 documents
# indexed 3807 documents
# indexed 3808 documents
# indexed 3809 documents
# indexed 3810 documents
# indexed 3811 documents
# indexed 3812 documents
# indexed 3813 documents
# indexed 3814 documents
# indexed 3815 documents
# indexed 3816 documents
# indexed 3817 documents
# indexed 3818 documents
# indexed 3819 documents
# indexed 3820 documents
# indexed 3821 documents
# indexed 3822 documents
# indexed 3823 documents
# indexed 3824 documents
# indexed 3825 documents
# indexed 3826 documents
# indexed 3827 documents
# indexed 3828 documents
# indexed 3829 documents
# indexed 3830 documents
# indexed 3831 documents
# indexed 3832 documents
# indexed 3833 documents
# indexed 3834 documents
# indexed 3835 documents
# indexed 3836 documents
# indexed 3837 documents
# indexed 3838 documents
# indexed 3839 documents
# indexed 3840 documents
# indexed 3841 documents
# indexed 3842 documents
# indexed 3843 documents
# indexed 3844 documents
# indexed 3845 documents
# indexed 3846 documents
# indexed 3847 documents
# indexed 3848 documents
# indexed 3849 documents
# indexed 3850 documents
# indexed 3851 documents
# indexed 3852 documents
# indexed 3853 documents
# indexed 3854 documents
# indexed 3855 documents
# indexed 3856 documents
# indexed 3857 documents
# indexed 3858 documents
# indexed 3859 documents
# indexed 3860 documents
# indexed 3861 documents
# indexed 3862 documents
# indexed 3863 documents
# indexed 3864 documents
# indexed 3865 documents
# indexed 3866 documents
# indexed 3867 documents
# indexed 3868 documents
# indexed 3869 documents
# indexed 3870 documents
# indexed 3871 documents
# indexed 3872 documents
# indexed 3873 documents
# indexed 3874 documents
# indexed 3875 documents
# indexed 3876 documents
# indexed 3877 documents
# indexed 3878 documents
# indexed 3879 documents
# indexed 3880 documents
# indexed 3881 documents
# indexed 3882 documents
# indexed 3883 documents
# indexed 3884 documents
# indexed 3885 documents
# indexed 3886 documents
# indexed 3887 documents
# indexed 3888 documents
# indexed 3889 documents
# indexed 3890 documents
# indexed 3891 documents
# indexed 3892 documents
# indexed 3893 documents
# indexed 3894 documents
# indexed 3895 documents
# indexed 3896 documents
# indexed 3897 documents
# indexed 3898 documents
# indexed 3899 documents
# indexed 3900 documents
# indexed 3901 documents
# indexed 3902 documents
# indexed 3903 documents
# indexed 3904 documents
# indexed 3905 documents
# indexed 3906 documents
# indexed 3907 documents
# indexed 3908 documents
# indexed 3909 documents
# indexed 3910 documents
# indexed 3911 documents
# indexed 3912 documents
# indexed 3913 documents
# indexed 3914 documents
# indexed 3915 documents
# indexed 3916 documents
# indexed 3917 documents
# indexed 3918 documents
# indexed 3919 documents
# indexed 3920 documents
# indexed 3921 documents
# indexed 3922 documents
# indexed 3923 documents
# indexed 3924 documents
# indexed 3925 documents
# indexed 3926 documents
# indexed 3927 documents
# indexed 3928 documents
# indexed 3929 documents
# indexed 3930 documents
# indexed 3931 documents
# indexed 3932 documents
# indexed 3933 documents
# indexed 3934 documents
# indexed 3935 documents
# indexed 3936 documents
# indexed 3937 documents
# indexed 3938 documents
# indexed 3939 documents
# indexed 3940 documents
# indexed 3941 documents
# indexed 3942 documents
# indexed 3943 documents
# indexed 3944 documents
# indexed 3945 documents
# indexed 3946 documents
# indexed 3947 documents
# indexed 3948 documents
# indexed 3949 documents
# indexed 3950 documents
# indexed 3951 documents
# indexed 3952 documents
# indexed 3953 documents
# indexed 3954 documents
# indexed 3955 documents
# indexed 3956 documents
# indexed 3957 documents
# indexed 3958 documents
# indexed 3959 documents
# indexed 3960 documents
# indexed 3961 documents
# indexed 3962 documents
# indexed 3963 documents
# indexed 3964 documents
# indexed 3965 documents
# indexed 3966 documents
# indexed 3967 documents
# indexed 3968 documents
# indexed 3969 documents
# indexed 3970 documents
# indexed 3971 documents
# indexed 3972 documents
# indexed 3973 documents
# indexed 3974 documents
# indexed 3975 documents
# indexed 3976 documents
# indexed 3977 documents
# indexed 3978 documents
# indexed 3979 documents
# indexed 3980 documents
# indexed 3981 documents
# indexed 3982 documents
# indexed 3983 documents
# indexed 3984 documents
# indexed 3985 documents
# indexed 3986 documents
# indexed 3987 documents
# indexed 3988 documents
# indexed 3989 documents
# indexed 3990 documents
# indexed 3991 documents
# indexed 3992 documents
# indexed 3993 documents
# indexed 3994 documents
# indexed 3995 documents
# indexed 3996 documents
# indexed 3997 documents
# indexed 3998 documents
# indexed 3999 documents
# indexed 4000 documents
# indexed 4001 documents
# indexed 4002 documents
# indexed 4003 documents
# indexed 4004 documents
# indexed 4005 documents
# indexed 4006 documents
# indexed 4007 documents
# indexed 4008 documents
# indexed 4009 documents
# indexed 4010 documents
# indexed 4011 documents
# indexed 4012 documents
# indexed 4013 documents
# indexed 4014 documents
# indexed 4015 documents
# indexed 4016 documents
# indexed 4017 documents
# indexed 4018 documents
# indexed 4019 documents
# indexed 4020 documents
# indexed 4021 documents
# indexed 4022 documents
# indexed 4023 documents
# indexed 4024 documents
# indexed 4025 documents
# indexed 4026 documents
# indexed 4027 documents
# indexed 4028 documents
# indexed 4029 documents
# indexed 4030 documents
# indexed 4031 documents
# indexed 4032 documents
# indexed 4033 documents
# indexed 4034 documents
# indexed 4035 documents
# indexed 4036 documents
# indexed 4037 documents
# indexed 4038 documents
# indexed 4039 documents
# indexed 4040 documents
# indexed 4041 documents
# indexed 4042 documents
# indexed 4043 documents
# indexed 4044 documents
# indexed 4045 documents
# indexed 4046 documents
# indexed 4047 documents
# indexed 4048 documents
# indexed 4049 documents
# indexed 4050 documents
# indexed 4051 documents
# indexed 4052 documents
# indexed 4053 documents
# indexed 4054 documents
# indexed 4055 documents
# indexed 4056 documents
# indexed 4057 documents
# indexed 4058 documents
# indexed 4059 documents
# indexed 4060 documents
# indexed 4061 documents
# indexed 4062 documents
# indexed 4063 documents
# indexed 4064 documents
# indexed 4065 documents
# indexed 4066 documents
# indexed 4067 documents
# indexed 4068 documents
# indexed 4069 documents
# indexed 4070 documents
# indexed 4071 documents
# indexed 4072 documents
# indexed 4073 documents
# indexed 4074 documents
# indexed 4075 documents
# indexed 4076 documents
# indexed 4077 documents
# indexed 4078 documents
# indexed 4079 documents
# indexed 4079 docs to index `government`, failed to index 0 docs

# %%
output_file = open("improved_retrieved.txt","w+")

es_conn = Elasticsearch(ES_HOSTS)
for query_id, query in queries:
    res = search(query, es_conn, EVAL_INDEX_NAME)
    write_trec_file(query_id, res, output_file)

output_file.close()

# %%
# !./trec_eval-master/trec_eval ./practice_data/government/qrels/gov.qrels improved_retrieved.txt
